# %%
from time import time
import pandas as pd

import matplotlib

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

import tensorflow as tf

from tensorflow.python.keras.models import Model, Sequential
from tensorflow.python.keras.layers import Input, Embedding, LSTM, GRU, Conv1D, Conv2D, GlobalMaxPool1D, Dense, Dropout

from util import make_w2v_embeddings
from util import split_and_zero_padding
from util import ManDist

# %%
'''with open('./data/train_snli.txt','r') as train_data:
    td=train_data.read()
    train_data.close()
with open('./data/train_snli.txt','w') as train_data:
    for word in td:
        if word=="0" or word=="1":
           word=word.replace(word, word+"\n")
    train_data.seek(0)
    train_data.write(td)
    train_data.close()  '''

# %%
#train_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6a115dfddf45> in <module>
# ----> 1 train_data
#
# NameError: name 'train_data' is not defined

# %%
''''import pandas
dataframe=pandas.read_csv("./data/train_snli.txt",delimiter="\t")
dataframe.to_csv("./data/train_snli.csv", encoding='utf-8', index=False)'''

# %%
df = pd.read_csv (r'./data/final.csv')

# %%
df
# Out:
#                                                 sentence1  \
# 0       A person on a horse jumps over a broken down a...
# 1       A person on a horse jumps over a broken down a...
# 2                   Children smiling and waving at camera
# 3                   Children smiling and waving at camera
# 4       A boy is jumping on skateboard in the middle o...
# 5       A boy is jumping on skateboard in the middle o...
# 6       An older man sits with his orange juice at a s...
# 7                Two blond women are hugging one another.
# 8                Two blond women are hugging one another.
# 9       A few people in a restaurant setting, one of t...
# 10      A few people in a restaurant setting, one of t...
# 11      An older man is drinking orange juice at a res...
# 12      An older man is drinking orange juice at a res...
# 13      A man with blond-hair, and a brown shirt drink...
# 14      A man with blond-hair, and a brown shirt drink...
# 15      Two women who just had lunch hugging and sayin...
# 16      Two women who just had lunch hugging and sayin...
# 17      Two women, holding food carryout containers, hug.
# 18      Two women, holding food carryout containers, hug.
# 19      A Little League team tries to catch a runner s...
# 20      A Little League team tries to catch a runner s...
# 21      The school is having a special event in order ...
# 22      The school is having a special event in order ...
# 23      High fashion ladies wait outside a tram beside...
# 24      High fashion ladies wait outside a tram beside...
# 25      A man, woman, and child enjoying themselves on...
# 26      A man, woman, and child enjoying themselves on...
# 27      People waiting to get on a train or just getti...
# 28      People waiting to get on a train or just getti...
# 29       A couple playing with a little boy on the beach.
# ...                                                   ...
# 367343  A group of young children wearing blue robes a...
# 367344  A group of young children wearing blue robes a...
# 367345  A group of young children wearing blue robes a...
# 367346  A group of young children wearing blue robes a...
# 367347  A group of young children wearing blue robes a...
# 367348  A group of young children wearing blue robes a...
# 367349  A group of young children wearing blue robes a...
# 367350  A group of young children wearing blue robes a...
# 367351  A group of young children wearing blue robes a...
# 367352  A group of young children wearing blue robes a...
# 367353  Two men standing outside wearing jackets and c...
# 367354  Two men standing outside wearing jackets and c...
# 367355  Two men dressed jackets and hats are standing ...
# 367356  Two men dressed jackets and hats are standing ...
# 367357    Four children are standing to pose for a photo.
# 367358    Four children are standing to pose for a photo.
# 367359    A surfer looks behind him to see the next wave.
# 367360    A surfer looks behind him to see the next wave.
# 367361  A group of people in orange life vests are boa...
# 367362  A group of people in orange life vests are boa...
# 367363  A group of four kids stand in front of a statu...
# 367364  A group of four kids stand in front of a statu...
# 367365     a kid doing tricks on a skateboard on a bridge
# 367366     a kid doing tricks on a skateboard on a bridge
# 367367       A dog with a blue collar plays ball outside.
# 367368       A dog with a blue collar plays ball outside.
# 367369                Four dirty and barefooted children.
# 367370                Four dirty and barefooted children.
# 367371  A man is surfing in a bodysuit in beautiful bl...
# 367372  A man is surfing in a bodysuit in beautiful bl...
#
#                                                 sentence2  is_duplicate
# 0           A person is at a diner, ordering an omelette.             0
# 1                       A person is outdoors, on a horse.             1
# 2                              There are children present             1
# 3                                   The kids are frowning             0
# 4                       The boy skates down the sidewalk.             0
# 5                     The boy does a skateboarding trick.             1
# 6                                   A boy flips a burger.             0
# 7                                 The women are sleeping.             0
# 8                      There are women showing affection.             1
# 9              The people are sitting at desks in school.             0
# 10                        The diners are at a restaurant.             1
# 11                               A man is drinking juice.             1
# 12           Two women are at a restaurant drinking wine.             0
# 13      A blond man wearing a brown shirt is reading a...             0
# 14            A blond man drinking water from a fountain.             1
# 15      The friends scowl at each other over a full di...             0
# 16                   There are two woman in this picture.             1
# 17      Two groups of rival gang members flipped each ...             0
# 18                              Two women hug each other.             1
# 19                  A team is trying to tag a runner out.             1
# 20                  A team is playing baseball on Saturn.             0
# 21                      A school hosts a basketball game.             0
# 22                          A school is hosting an event.             1
# 23          The women do not care what clothes they wear.             0
# 24                           Women are waiting by a tram.             1
# 25                     A family of three is at the beach.             1
# 26             A family of three is at the mall shopping.             0
# 27               There are people just getting on a train             1
# 28                   There are people waiting on a train.             1
# 29       A couple are playing with a young child outside.             1
# ...                                                   ...           ...
# 367343                         The children are sleeping.             0
# 367344               A group of adults sing to the crowd.             0
# 367345                  the children are at home sleeping             0
# 367346                            some chilldren standing             1
# 367347              A group of children play tag outside.             0
# 367348                    The crowd can see the children.             1
# 367349  A group of children stand in front of a group ...             1
# 367350                        Children are holding hands.             1
# 367351      A group of children stand in front of a crowd             1
# 367352                             Children are swimming.             0
# 367353                              Two men are outdoors.             1
# 367354                              Two men are swimming.             0
# 367355                     2 well dressed men are outside             1
# 367356                                3 women are outside             0
# 367357              Four children are posing for a photo.             1
# 367358      Four adults are standing to pose for a photo.             0
# 367359      A surfer stays attentive to his surroundings.             1
# 367360  A surfer standing on the beach next to his board.             0
# 367361                            The life vests are red.             0
# 367362                                  There are people.             1
# 367363                                the kids are seated             0
# 367364                                 four kids standing             1
# 367365                             a kid is skateboarding             1
# 367366                                    a kid is inside             0
# 367367                              a dog is on the couch             0
# 367368                                   a dog is outside             1
# 367369                     four children have dirty feet.             1
# 367370           four kids won awards for 'cleanest feet'             0
# 367371  A man in a business suit is heading to a board...             0
# 367372  On the beautiful blue water there is a man in ...             1
#
# [367373 rows x 3 columns]

# %%
target=df.is_duplicate
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size=0.2)
train.to_csv("./data/train_s.csv", encoding='utf-8', index=False)
test.to_csv("./data/test_s.csv", encoding='utf-8', index=False)

# %%
train
# Out:
#                                                 sentence1  \
# 254774                          many cars in the high way
# 354441                 A group of kids playing dodgeball.
# 127965  Three women in sports bikinis are playing voll...
# 299541  A display of different alcoholic and non alcoh...
# 211303  Several young people walk across the water on ...
# 298130  A screaming man playing hand-ball makes a thro...
# 114173  A girl in a rope harness is suspended in the a...
# 308357        person on snowboard in the air doing a jump
# 21663   A girl rides a unicycle as another rides a sco...
# 100552       An Asian couple kisses during their wedding.
# 271924  two girls wearing sweatshirts and jeans trying...
# 217286  Workers wearing yellow hard hats while working...
# 162375             A man is backpacking up a grassy hill.
# 212217  A smiling, happy-appearing blond woman with ba...
# 91675   A man is riding his bicycle downhill in rough ...
# 92460   A man in a sports uniform is being held up in ...
# 216241           Two young kids are playing in the grass.
# 364377  A teenager wearing a black t-shirt is skating ...
# 350228  A man holding a microphone on the stage in lig...
# 286373  A small red and white race car is competing du...
# 179345  Two tall basketball players are attempting to ...
# 130000  Group of people in historical costumes taking ...
# 269536  A group of students working together in a clas...
# 35124   A man is seen covering his face in a crowd of ...
# 143574  The black and white dog is biting the brown an...
# 219521  A man in a brown jacket and green hat is stand...
# 306294  A woman is at the beginning stage of knitting ...
# 22275   A young girl in a yellow dress walking at a ba...
# 107894  A man with a balloon hat and a woman wearing a...
# 122144              People looking at a painting of Cher.
# ...                                                   ...
# 71110   A man in a blue swimsuit and a red beanie knee...
# 285917  Woman in black walks with child past a wall mu...
# 346996  Man in black swim trunks jumping in a swimming...
# 172963      Man in fedora plays his black guitar outside.
# 276363                Two white dogs playing in a forest.
# 119073  A mule pulling a carriage with a man inside al...
# 305947  Two young men play basketball while crowd look...
# 33190   Two women in black skirts are standing on gree...
# 226556  Many adults and children eat a meal in a publi...
# 252892  Two people wearing racing uniforms are riding ...
# 269586  A brown and white dog is running across a brow...
# 280681             A child with blond-hair and blue eyes.
# 152230  The large brown and white dog is running throu...
# 244178              A man paddles on a blue boogie board.
# 274102     A group of people dressed in costumes singing.
# 305001  A busy city street with large buildings that h...
# 169507      A man talking on his cellphone while driving.
# 308847  A man with a colorful array of pinwheels is st...
# 132517  A person riding a bicycle going over a raised ...
# 8657    Two guys, one wearing a blue jacket and the ot...
# 298410  A man and a little girl in a grassy area are p...
# 139466  A man walks along a sidewalk outside of a reco...
# 5279    A young blond girl with a pink shirt on jumps ...
# 360205  A woman is holding a little girl who is trying...
# 144788        A man is seen coughing in a crowded street.
# 99824   A woman in a green plaid coat is standing in f...
# 265055      A black dog jumps over a pole on green grass.
# 163452  A man in a white shirt and blue jeans is talki...
# 316159  A man riding a horse jumps over two hurdles at...
# 121712  Two women smiling and laughing that are wearin...
#
#                                                 sentence2  is_duplicate
# 254774                              A small country road.             0
# 354441  The clothes are copying their homework from of...             0
# 127965                 The women are on a snowy mountain.             0
# 299541                             a display of beverages             1
# 211303                          People walking on stones.             1
# 298130                               A man is at the DMV.             0
# 114173  The girl is having a lovely late supper at the...             0
# 308357                                    A person surfs.             0
# 21663                         Two girls going for a ride.             1
# 100552                     The couple is getting married.             1
# 271924                      The girls are wearing skirts.             0
# 217286                       No worker is wearing a hat..             0
# 162375                        A man skis down a mountain.             0
# 212217  The man sets his backpack on the ground to tak...             0
# 91675                      The man is not on a bike path.             1
# 92460                         No one is holding anything.             0
# 216241                               Two men are playing.             0
# 364377                    The teenager is roller blading.             0
# 350228               A man is speaking in the microphone.             1
# 286373                     There are no cars at the race.             0
# 179345  Basketball players are attempting to block a t...             1
# 130000                     A group of dogs chasing a cat.             0
# 269536                                  Nobody is working             0
# 35124                                 a bird was on rocks             1
# 143574  The black and white dog is licking the brown a...             0
# 219521                      A man is sleeping in his bed.             0
# 306294        A woman is at the ending stage of knitting.             0
# 22275                        A couple of boys play catch.             0
# 107894  A naked man and woman are frolicking in the wo...             0
# 122144                                Dogs playing poker.             0
# ...                                                   ...           ...
# 71110                       A man is making a sandcastle.             1
# 285917         A woman holds a child while wearing black.             1
# 346996               The man is drinking a beer in a pub.             0
# 172963                               the man has a guitar             1
# 276363                  Two dogs are playing in the pool.             0
# 119073  A dog  pulling a carriage with a man inside al...             0
# 305947                  The women are playing basketball.             0
# 33190                              Two women are outside.             1
# 226556                              People gather to eat.             1
# 252892         Two people are driving trucks down a hill.             0
# 269586                     A dog is jumping on the couch.             0
# 280681                          The child has brown hair.             0
# 152230                  A horse is jumping over a hurtle.             0
# 244178                       Man laying out on the beach.             0
# 274102                        People in costumes singing.             1
# 305001              The street is full of suburban homes.             0
# 169507   A man is talking on his cellphone while walking.             0
# 308847  A man with a single monotone pinwheel is stand...             0
# 132517             A person riding a scooter over a ramp.             0
# 8657                          Two men play an instrument.             1
# 298410  The man and two children are chopping down a t...             0
# 139466                                The man is outside.             1
# 5279                A young girl is jumping into the air.             1
# 360205                      A woman is holding twin boys.             0
# 144788                     A man coughs in a busy street.             1
# 99824      The woman in green plaid is at the laundromat.             1
# 265055                         Black dog jumps over pole/             1
# 163452                          A man talks into a phone.             1
# 316159                       A man performs at the event.             1
# 121712                                 Two woman are mad.             0
#
# [293898 rows x 3 columns]

# %%
embedding_dim = 300
max_seq_length = 20
use_w2v = True

# %%
train, embeddings = make_w2v_embeddings(train, embedding_dim=embedding_dim, empty_w2v=not use_w2v)
# Out:
# Loading word2vec model(it may takes 2-3 mins) ...
# 130,000 sentences embedded.
# 183,000 sentences embedded.
# 15,000 sentences embedded.
# 178,000 sentences embedded.
# 4,000 sentences embedded.
# 284,000 sentences embedded.
# 236,000 sentences embedded.
# 219,000 sentences embedded.
# 199,000 sentences embedded.
# 70,000 sentences embedded.
# 76,000 sentences embedded.
# 355,000 sentences embedded.
# 159,000 sentences embedded.
# 303,000 sentences embedded.
# 264,000 sentences embedded.
# 307,000 sentences embedded.
# 166,000 sentences embedded.
# 336,000 sentences embedded.
# 351,000 sentences embedded.
# 347,000 sentences embedded.
# 191,000 sentences embedded.
# 81,000 sentences embedded.
# 356,000 sentences embedded.
# 247,000 sentences embedded.
# 50,000 sentences embedded.
# 224,000 sentences embedded.
# 87,000 sentences embedded.
# 107,000 sentences embedded.
# 225,000 sentences embedded.
# 301,000 sentences embedded.
# 305,000 sentences embedded.
# 359,000 sentences embedded.
# 344,000 sentences embedded.
# 171,000 sentences embedded.
# 262,000 sentences embedded.
# 101,000 sentences embedded.
# 349,000 sentences embedded.
# 52,000 sentences embedded.
# 360,000 sentences embedded.
# 106,000 sentences embedded.
# 98,000 sentences embedded.
# 163,000 sentences embedded.
# 367,000 sentences embedded.
# 276,000 sentences embedded.
# 105,000 sentences embedded.
# 361,000 sentences embedded.
# 365,000 sentences embedded.
# 228,000 sentences embedded.
# 109,000 sentences embedded.
# 142,000 sentences embedded.
# 210,000 sentences embedded.
# 146,000 sentences embedded.
# 348,000 sentences embedded.
# 45,000 sentences embedded.
# 279,000 sentences embedded.
# 296,000 sentences embedded.
# 226,000 sentences embedded.
# 113,000 sentences embedded.
# 121,000 sentences embedded.
# 306,000 sentences embedded.
# 280,000 sentences embedded.
# 156,000 sentences embedded.
# 214,000 sentences embedded.
# 320,000 sentences embedded.
# 273,000 sentences embedded.
# 6,000 sentences embedded.
# 129,000 sentences embedded.
# 267,000 sentences embedded.
# 161,000 sentences embedded.
# 332,000 sentences embedded.
# 237,000 sentences embedded.
# 341,000 sentences embedded.
# 289,000 sentences embedded.
# 313,000 sentences embedded.
# 319,000 sentences embedded.
# 2,000 sentences embedded.
# 322,000 sentences embedded.
# 91,000 sentences embedded.
# 71,000 sentences embedded.
# 202,000 sentences embedded.
# 138,000 sentences embedded.
# 278,000 sentences embedded.
# 41,000 sentences embedded.
# 68,000 sentences embedded.
# 122,000 sentences embedded.
# 321,000 sentences embedded.
# 300,000 sentences embedded.
# 330,000 sentences embedded.
# 22,000 sentences embedded.
# 36,000 sentences embedded.
# 203,000 sentences embedded.
# 104,000 sentences embedded.
# 162,000 sentences embedded.
# 340,000 sentences embedded.
# 58,000 sentences embedded.
# 283,000 sentences embedded.
# 67,000 sentences embedded.
# 3,000 sentences embedded.
# 358,000 sentences embedded.
# 66,000 sentences embedded.
# 120,000 sentences embedded.
# 265,000 sentences embedded.
# 352,000 sentences embedded.
# 10,000 sentences embedded.
# 287,000 sentences embedded.
# 19,000 sentences embedded.
# 189,000 sentences embedded.
# 207,000 sentences embedded.
# 291,000 sentences embedded.
# 175,000 sentences embedded.
# 47,000 sentences embedded.
# 241,000 sentences embedded.
# 317,000 sentences embedded.
# 86,000 sentences embedded.
# 152,000 sentences embedded.
# 200,000 sentences embedded.
# 12,000 sentences embedded.
# 77,000 sentences embedded.
# 270,000 sentences embedded.
# 136,000 sentences embedded.
# 244,000 sentences embedded.
# 160,000 sentences embedded.
# 29,000 sentences embedded.
# 9,000 sentences embedded.
# 158,000 sentences embedded.
# 145,000 sentences embedded.
# 193,000 sentences embedded.
# 181,000 sentences embedded.
# 295,000 sentences embedded.
# 205,000 sentences embedded.
# 165,000 sentences embedded.
# 141,000 sentences embedded.
# 233,000 sentences embedded.
# 124,000 sentences embedded.
# 85,000 sentences embedded.
# 140,000 sentences embedded.
# 157,000 sentences embedded.
# 227,000 sentences embedded.
# 56,000 sentences embedded.
# 325,000 sentences embedded.
# 238,000 sentences embedded.
# 323,000 sentences embedded.
# 192,000 sentences embedded.
# 88,000 sentences embedded.
# 298,000 sentences embedded.
# 229,000 sentences embedded.
# 329,000 sentences embedded.
# 216,000 sentences embedded.
# 297,000 sentences embedded.
# 211,000 sentences embedded.
# 93,000 sentences embedded.
# 139,000 sentences embedded.
# 164,000 sentences embedded.
# 84,000 sentences embedded.
# 311,000 sentences embedded.
# 261,000 sentences embedded.
# 25,000 sentences embedded.
# 144,000 sentences embedded.
# 167,000 sentences embedded.
# 61,000 sentences embedded.
# 40,000 sentences embedded.
# 173,000 sentences embedded.
# 53,000 sentences embedded.
# 110,000 sentences embedded.
# 190,000 sentences embedded.
# 294,000 sentences embedded.
# 49,000 sentences embedded.
# 253,000 sentences embedded.
# 235,000 sentences embedded.
# 114,000 sentences embedded.
# 220,000 sentences embedded.
# 83,000 sentences embedded.
# 48,000 sentences embedded.
# 246,000 sentences embedded.
# 281,000 sentences embedded.
# 27,000 sentences embedded.
# 35,000 sentences embedded.
# 266,000 sentences embedded.
# 32,000 sentences embedded.
# 55,000 sentences embedded.
# 240,000 sentences embedded.
# 239,000 sentences embedded.
# 248,000 sentences embedded.
# 123,000 sentences embedded.
# 5,000 sentences embedded.
# 196,000 sentences embedded.
# 252,000 sentences embedded.
# 64,000 sentences embedded.
# 285,000 sentences embedded.
# 326,000 sentences embedded.
# 198,000 sentences embedded.
# 95,000 sentences embedded.
# 254,000 sentences embedded.
# 174,000 sentences embedded.
# 63,000 sentences embedded.
# 172,000 sentences embedded.
# 125,000 sentences embedded.
# 302,000 sentences embedded.
# 179,000 sentences embedded.
# 26,000 sentences embedded.
# 116,000 sentences embedded.
# 342,000 sentences embedded.
# 194,000 sentences embedded.
# 150,000 sentences embedded.
# 54,000 sentences embedded.
# 51,000 sentences embedded.
# 324,000 sentences embedded.
# 38,000 sentences embedded.
# 259,000 sentences embedded.
# 208,000 sentences embedded.
# 316,000 sentences embedded.
# 65,000 sentences embedded.
# 243,000 sentences embedded.
# 275,000 sentences embedded.
# 62,000 sentences embedded.
# 100,000 sentences embedded.
# 24,000 sentences embedded.
# 28,000 sentences embedded.
# 74,000 sentences embedded.
# 354,000 sentences embedded.
# 334,000 sentences embedded.
# 204,000 sentences embedded.
# 197,000 sentences embedded.
# 343,000 sentences embedded.
# 131,000 sentences embedded.
# 274,000 sentences embedded.
# 128,000 sentences embedded.
# 177,000 sentences embedded.
# 44,000 sentences embedded.
# 314,000 sentences embedded.
# 117,000 sentences embedded.
# 99,000 sentences embedded.
# 135,000 sentences embedded.
# 89,000 sentences embedded.
# 153,000 sentences embedded.
# 169,000 sentences embedded.
# 60,000 sentences embedded.
# 118,000 sentences embedded.
# 333,000 sentences embedded.
# 168,000 sentences embedded.
# 268,000 sentences embedded.
# 90,000 sentences embedded.
# 290,000 sentences embedded.
# 363,000 sentences embedded.
# 7,000 sentences embedded.
# 249,000 sentences embedded.
# 212,000 sentences embedded.
# 79,000 sentences embedded.
# 288,000 sentences embedded.
# 315,000 sentences embedded.
# 255,000 sentences embedded.
# 271,000 sentences embedded.
# 176,000 sentences embedded.
# 213,000 sentences embedded.
# 222,000 sentences embedded.
# 256,000 sentences embedded.
# 132,000 sentences embedded.
# 170,000 sentences embedded.
# 282,000 sentences embedded.
# 201,000 sentences embedded.
# 346,000 sentences embedded.
# 364,000 sentences embedded.
# 148,000 sentences embedded.
# 42,000 sentences embedded.
# 134,000 sentences embedded.
# 184,000 sentences embedded.
# 231,000 sentences embedded.
# 149,000 sentences embedded.
# 182,000 sentences embedded.
# 151,000 sentences embedded.
# 353,000 sentences embedded.
# 269,000 sentences embedded.
# 112,000 sentences embedded.
# 119,000 sentences embedded.
# 293,000 sentences embedded.
# 263,000 sentences embedded.
# 39,000 sentences embedded.
# 286,000 sentences embedded.
# 260,000 sentences embedded.
# 147,000 sentences embedded.
# 258,000 sentences embedded.
# 33,000 sentences embedded.
# 37,000 sentences embedded.
# 277,000 sentences embedded.
# 250,000 sentences embedded.
# 127,000 sentences embedded.
# 80,000 sentences embedded.
# 218,000 sentences embedded.
# 232,000 sentences embedded.
# 221,000 sentences embedded.
# 14,000 sentences embedded.
# 331,000 sentences embedded.
# 299,000 sentences embedded.
# 251,000 sentences embedded.
# 59,000 sentences embedded.
# 257,000 sentences embedded.
# 17,000 sentences embedded.
# 242,000 sentences embedded.

# %%
# Split to train validation
validation_size = int(len(train) * 0.1)
training_size = len(train) - validation_size

# %%
X = train[['sentence1', 'sentence2']]
Y = train['is_duplicate']

# %%
X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y, test_size=validation_size)

# %%
X_train = split_and_zero_padding(X_train, max_seq_length)
X_validation = split_and_zero_padding(X_validation, max_seq_length)

# %%
# Convert labels to their numpy representations
Y_train = Y_train.values
Y_validation = Y_validation.values

# %%
# Make sure everything is ok
assert X_train['left'].shape == X_train['right'].shape
assert len(X_train['left']) == len(Y_train)

# %%
# Model variables
gpus = 2
batch_size = 1024 * gpus
n_epoch = 100
n_hidden = 50

# %%
# Define the shared model
x = Sequential()
x.add(Embedding(len(embeddings), embedding_dim,weights=[embeddings], input_shape=(max_seq_length,), trainable=False))
#x.add(Embedding(len(embeddings), embedding_dim, weights=[embeddings], input_shape=(max_seq_length,), trainable=False)) Requires GPU support
# Out:
# WARNING:tensorflow:From C:\Users\subhashree hazra\Anaconda3\lib\site-packages\tensorflow\python\keras\initializers.py:119: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
#CNN
x.add(Conv1D(250, kernel_size=5, activation='relu'))
x.add(GlobalMaxPool1D())
x.add(Dense(250, activation='relu'))
x.add(Dropout(0.3))
x.add(Dense(5, activation='sigmoid'))
x.add(Dense(2, activation='tanh')

# %%
# LSTM
x.add(LSTM((n_hidden),return_sequences=False))
# Out:
# WARNING:tensorflow:From C:\Users\subhashree hazra\Anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
shared_model = x

# %%
# The visible layer
left_input = Input(shape=(max_seq_length,), dtype='int32')
right_input = Input(shape=(max_seq_length,), dtype='int32')

# %%
# Pack it all up into a Manhattan Distance model
malstm_distance = ManDist()([shared_model(left_input), shared_model(right_input)])
model = Model(inputs=[left_input, right_input], outputs=[malstm_distance])
# Out:
# WARNING:tensorflow:Entity <bound method ManDist.call of <util.ManDist object at 0x0000022EA5F3F160>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ManDist.call of <util.ManDist object at 0x0000022EA5F3F160>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method ManDist.call of <util.ManDist object at 0x0000022EA5F3F160>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ManDist.call of <util.ManDist object at 0x0000022EA5F3F160>>: AttributeError: module 'gast' has no attribute 'Num'

# %%
model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(), metrics=['accuracy'])
model.summary()
shared_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 20)]         0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 20)]         0
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 50)           8003400     input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# man_dist (ManDist)              (None, 1)            0           sequential[1][0]
#                                                                  sequential[2][0]
# ==================================================================================================
# Total params: 8,003,400
# Trainable params: 70,200
# Non-trainable params: 7,933,200
# __________________________________________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 20, 300)           7933200
# _________________________________________________________________
# lstm (LSTM)                  (None, 50)                70200
# =================================================================
# Total params: 8,003,400
# Trainable params: 70,200
# Non-trainable params: 7,933,200
# _________________________________________________________________

# %%
# Start trainings
training_start_time = time()
malstm_trained = model.fit([X_train['left'], X_train['right']], Y_train,
                           batch_size=batch_size, epochs=n_epoch,
                           validation_data=([X_validation['left'], X_validation['right']], Y_validation))
training_end_time = time()
print("Training time finished.\n%d epochs in %12.2f" % (n_epoch,
                                                        training_end_time - training_start_time))

model.save('./data/SiameseLSTM.h5')
# Out:
# Train on 264509 samples, validate on 29389 samples
# Epoch 1/100
# 264509/264509 [==============================] - 80s 301us/sample - loss: 0.1412 - acc: 0.8258 - val_loss: 0.1528 - val_acc: 0.8002
# Epoch 2/100
# 264509/264509 [==============================] - 77s 291us/sample - loss: 0.
100
# 264509/264509 [==============================] - 76s 287us/sample - loss: 0.1300 - acc: 0.8456 - val_loss: 0.1511 - val_acc: 0.8018
# Epoch 82/100
# 264509/264509 [==============================] - 76s 287us/sample - loss: 0.1300 - acc: 0.8455 - val_loss: 0.1511 - val_acc: 0.8019
# Epoch 83/100
# 264509/264509 [==============================] - 76s 287us/sample - loss: 0.1299 - acc: 0.8454 - val_loss: 0.1510 - val_acc: 0.8021
# Epoch 84/100
# 264509/264509 [==============================] - 76s 287us/sample - loss: 0.1298 - acc: 0.8455 - val_loss: 0.1514 - val_acc: 0.8016
# Epoch 85/100
# 264509/264509 [==============================] - 75s 283us/sample - loss: 0.1297 - acc: 0.8460 - val_loss: 0.1511 - val_acc: 0.8020
# Epoch 86/100
# 264509/264509 [==============================] - 54s 205us/sample - loss: 0.1296 - acc: 0.8457 - val_loss: 0.1511 - val_acc: 0.8012
# Epoch 87/100
# 264509/264509 [==============================] - 50s 189us/sample - loss: 0.1295 - acc: 0.8463 - val_loss: 0.1512 - val_acc: 0.8007
# Epoch 88/100
# 264509/264509 [==============================] - 50s 190us/sample - loss: 0.1295 - acc: 0.8464 - val_loss: 0.1514 - val_acc: 0.8008
# Epoch 89/100
# 264509/264509 [==============================] - 54s 203us/sample - loss: 0.1295 - acc: 0.8463 - val_loss: 0.1512 - val_acc: 0.8005
# Epoch 90/100
# 264509/264509 [==============================] - 54s 205us/sample - loss: 0.1293 - acc: 0.8467 - val_loss: 0.1511 - val_acc: 0.8007
# Epoch 91/100
# 264509/264509 [==============================] - 55s 209us/sample - loss: 0.1292 - acc: 0.8470 - val_loss: 0.1515 - val_acc: 0.7993
# Epoch 92/100
# 264509/264509 [==============================] - 55s 207us/sample - loss: 0.1291 - acc: 0.8469 - val_loss: 0.1514 - val_acc: 0.7992
# Epoch 93/100
# 264509/264509 [==============================] - 54s 205us/sample - loss: 0.1291 - acc: 0.8468 - val_loss: 0.1513 - val_acc: 0.8007
# Epoch 94/100
# 264509/264509 [==============================] - 65s 246us/sample - loss: 0.1290 - acc: 0.8472 - val_loss: 0.1514 - val_acc: 0.8010
# Epoch 95/100
# 264509/264509 [==============================] - 77s 291us/sample - loss: 0.1289 - acc: 0.8473 - val_loss: 0.1512 - val_acc: 0.8013
# Epoch 96/100
# 264509/264509 [==============================] - 77s 291us/sample - loss: 0.1288 - acc: 0.8472 - val_loss: 0.1513 - val_acc: 0.8005
# Epoch 97/100
# 264509/264509 [==============================] - 77s 291us/sample - loss: 0.1288 - acc: 0.8480 - val_loss: 0.1512 - val_acc: 0.8006
# Epoch 98/100
# 264509/264509 [==============================] - 77s 291us/sample - loss: 0.1287 - acc: 0.8479 - val_loss: 0.1514 - val_acc: 0.7992
# Epoch 99/100
# 264509/264509 [==============================] - 77s 291us/sample - loss: 0.1286 - acc: 0.8481 - val_loss: 0.1512 - val_acc: 0.8009
# Epoch 100/100
# 264509/264509 [==============================] - 77s 291us/sample - loss: 0.1285 - acc: 0.8481 - val_loss: 0.1513 - val_acc: 0.8009
# Training time finished.
# 100 epochs in     10434.86

# %%
# Plot accuracy
plt.subplot(211)
plt.plot(malstm_trained.history['acc'])
plt.plot(malstm_trained.history['val_acc'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
# Out:
# C:\Users\subhashree hazra\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
# Plot loss
plt.subplot(212)
plt.plot(malstm_trained.history['loss'])
plt.plot(malstm_trained.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
# Out:
# C:\Users\subhashree hazra\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
plt.tight_layout(h_pad=1.0)
plt.savefig('./data/history-graph.png')

print(str(malstm_trained.history['val_acc'][-1])[:6] +
      "(max: " + str(max(malstm_trained.history['val_acc']))[:6] + ")")
print("Done.")
# Out:
# 0.8009(max: 0.8044)
# Done.
